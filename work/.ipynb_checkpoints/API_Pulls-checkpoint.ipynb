# %%
import pandas as pd
import requests
import json
import datetime as dt
from api_keys import api_key

# %%
url = "https://api.the-odds-api.com/v3/odds/?"
sport = "basketball_nba"
ml_query_url = f"{url}apiKey={api_key}&sport={sport}&region=us"
ml_response = requests.get(ml_query_url).json()
s_query_url = f"{url}apiKey={api_key}&sport={sport}&region=us&mkt=spreads"
s_response = requests.get(s_query_url).json()
t_query_url = f"{url}apiKey={api_key}&sport={sport}&region=us&mkt=totals"
t_response = requests.get(t_query_url).json()

# %%
t_response
# Out:
# {'success': True,
#  'data': [{'sport_key': 'basketball_nba',
#    'sport_nice': 'NBA',
#    'teams': ['Los Angeles Clippers', 'Portland Trail Blazers'],
#    'commence_time': 1596906273,
#    'home_team': 'Portland Trail Blazers',
#    'sites': [{'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596907551,
#      'odds': {'totals': {'points': [232.5, 232.5],
#        'odds': [1.91, 1.91],
#        'position': ['over', 'under']}}},
#     {'site_key': 'bookmaker',
#      'site_nice': 'Bookmaker',
#      'last_update': 1596907296,
#      'odds': {'totals': {'position': ['over', 'under'],
#        'odds': [1.901, 1.917],
#        'points': [232.5, 232.5]}}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596907526,
#      'odds': {'totals': {'points': [239.5, 239.5],
#        'odds': [1.9, 1.89],
#        'position': ['over', 'under']}}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596907541,
#      'odds': {'totals': {'points': ['240.5', '240.5'],
#        'odds': [1.88, 1.9],
#        'position': ['over', 'under']}}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596907527,
#      'odds': {'totals': {'points': [239.5, 239.5],
#        'odds': [1.9, 1.89],
#        'position': ['over', 'under']}}},
#     {'site_key': 'mybookieag',
#      'site_nice': 'MyBookie.ag',
#      'last_update': 1596906727,
#      'odds': {'totals': {'points': ['232.5', '232.5'],
#        'odds': [1.91, 1.91],
#        'position': ['over', 'under']}}},
#     {'site_key': 'gtbets',
#      'site_nice': 'GTbets',
#      'last_update': 1596907546,
#      'odds': {'totals': {'points': [240.5, 240.5],
#        'odds': [1.87, 1.87],
#        'position': ['over', 'under']}}}],
#    'sites_count': 7},
#   {'sport_key': 'basketball_nba',
#    'sport_nice': 'NBA',
#    'teams': ['Denver Nuggets', 'Utah Jazz'],
#    'commence_time': 1596915600,
#    'home_team': 'Denver Nuggets',
#    'sites': [{'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596907527,
#      'odds': {'totals': {'points': [221.0, 221.0],
#        'odds': [1.9, 1.92],
#        'position': ['over', 'under']}}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596907541,
#      'odds': {'totals': {'points': ['221.0', '221.0'],
#        'odds': [1.9, 1.92],
#        'position': ['over', 'under']}}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596907526,
#      'odds': {'totals': {'points': [221.0, 221.0],
#        'odds': [1.9, 1.92],
#        'position': ['over', 'under']}}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596907542,
#      'odds': {'totals': {'points': [222.0, 222.0],
#        'odds': [1.952, 1.952],
#        'position': ['over', 'under']}}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596907534,
#      'odds': {'totals': {'points': [222.0, 222.0],
#        'odds': [1.9, 1.9],
#        'position': ['over', 'under']}}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596907547,
#      'odds': {'totals': {'points': [222.0, 222.0],
#        'odds': [1.9091, 1.9091],
#        'position': ['over', 'under']}}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596907531,
#      'odds': {'totals': {'points': [222.0, 222.0],
#        'odds': [1.909091, 1.909091],
#        'position': ['over', 'under']}}},
#     {'site_key': 'bookmaker',
#      'site_nice': 'Bookmaker',
#      'last_update': 1596907444,
#      'odds': {'totals': {'position': ['over', 'under'],
#        'odds': [1.909, 1.909],
#        'points': [222.0, 222.0]}}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596907551,
#      'odds': {'totals': {'points': [222.0, 222.0],
#        'odds': [1.91, 1.91],
#        'position': ['over', 'under']}}}],
#    'sites_count': 9},
#   {'sport_key': 'basketball_nba',
#    'sport_nice': 'NBA',
#    'teams': ['Indiana Pacers', 'Los Angeles Lakers'],
#    'commence_time': 1596924600,
#    'home_team': 'Indiana Pacers',
#    'sites': [{'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596907526,
#      'odds': {'totals': {'points': [218.5, 218.5],
#        'odds': [1.9, 1.92],
#        'position': ['over', 'under']}}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596907527,
#      'odds': {'totals': {'points': [218.5, 218.5],
#        'odds': [1.9, 1.92],
#        'position': ['over', 'under']}}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596907541,
#      'odds': {'totals': {'points': ['218.5', '218.5'],
#        'odds': [1.9, 1.92],
#        'position': ['over', 'under']}}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596907542,
#      'odds': {'totals': {'points': [219.0, 219.0],
#        'odds': [1.952, 1.952],
#        'position': ['over', 'under']}}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596907534,
#      'odds': {'totals': {'points': [219.0, 219.0],
#        'odds': [1.9, 1.9],
#        'position': ['over', 'under']}}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596907531,
#      'odds': {'totals': {'points': [218.5, 218.5],
#        'odds': [1.909091, 1.909091],
#        'position': ['over', 'under']}}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596907547,
#      'odds': {'totals': {'points': [218.5, 218.5],
#        'odds': [1.9091, 1.9091],
#        'position': ['over', 'under']}}},
#     {'site_key': 'bookmaker',
#      'site_nice': 'Bookmaker',
#      'last_update': 1596907444,
#      'odds': {'totals': {'position': ['over', 'under'],
#        'odds': [1.909, 1.909],
#        'points': [218.5, 218.5]}}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596907551,
#      'odds': {'totals': {'points': [219.0, 219.0],
#        'odds': [1.91, 1.91],
#        'position': ['over', 'under']}}}],
#    'sites_count': 9},
#   {'sport_key': 'basketball_nba',
#    'sport_nice': 'NBA',
#    'teams': ['Miami Heat', 'Phoenix Suns'],
#    'commence_time': 1596930000,
#    'home_team': 'Miami Heat',
#    'sites': [{'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596907526,
#      'odds': {'totals': {'points': [226.0, 226.0],
#        'odds': [1.93, 1.9],
#        'position': ['over', 'under']}}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596907527,
#      'odds': {'totals': {'points': [226.0, 226.0],
#        'odds': [1.93, 1.9],
#        'position': ['over', 'under']}}},
#     {'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596907541,
#      'odds': {'totals': {'points': ['226.0', '226.0'],
#        'odds': [1.93, 1.9],
#        'position': ['over', 'under']}}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596907542,
#      'odds': {'totals': {'points': [225.5, 225.5],
#        'odds': [1.909, 2.0],
#        'position': ['over', 'under']}}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596907534,
#      'odds': {'totals': {'points': [225.5, 225.5],
#        'odds': [1.87, 1.95],
#        'position': ['over', 'under']}}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596907547,
#      'odds': {'totals': {'points': [225.5, 225.5],
#        'odds': [1.9091, 1.9091],
#        'position': ['over', 'under']}}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596907531,
#      'odds': {'totals': {'points': [226.0, 226.0],
#        'odds': [1.909091, 1.909091],
#        'position': ['over', 'under']}}},
#     {'site_key': 'bookmaker',
#      'site_nice': 'Bookmaker',
#      'last_update': 1596907444,
#      'odds': {'totals': {'position': ['over', 'under'],
#        'odds': [1.909, 1.909],
#        'points': [226.5, 226.5]}}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596907551,
#      'odds': {'totals': {'points': [225.5, 225.5],
#        'odds': [1.91, 1.91],
#        'position': ['over', 'under']}}}],
#    'sites_count': 9},
#   {'sport_key': 'basketball_nba',
#    'sport_nice': 'NBA',
#    'teams': ['Dallas Mavericks', 'Milwaukee Bucks'],
#    'commence_time': 1596933600,
#    'home_team': 'Dallas Mavericks',
#    'sites': [{'site_key': 'betrivers',
#      'site_nice': 'BetRivers',
#      'last_update': 1596907541,
#      'odds': {'totals': {'points': ['234.5', '234.5'],
#        'odds': [1.92, 1.9],
#        'position': ['over', 'under']}}},
#     {'site_key': 'unibet',
#      'site_nice': 'Unibet',
#      'last_update': 1596907526,
#      'odds': {'totals': {'points': [234.5, 234.5],
#        'odds': [1.92, 1.9],
#        'position': ['over', 'under']}}},
#     {'site_key': 'draftkings',
#      'site_nice': 'DraftKings',
#      'last_update': 1596907527,
#      'odds': {'totals': {'points': [234.5, 234.5],
#        'odds': [1.92, 1.9],
#        'position': ['over', 'under']}}},
#     {'site_key': 'lowvig',
#      'site_nice': 'LowVig.ag',
#      'last_update': 1596907542,
#      'odds': {'totals': {'points': [233.5, 233.5],
#        'odds': [1.909, 2.0],
#        'position': ['over', 'under']}}},
#     {'site_key': 'betonlineag',
#      'site_nice': 'BetOnline.ag',
#      'last_update': 1596907534,
#      'odds': {'totals': {'points': [233.5, 233.5],
#        'odds': [1.87, 1.95],
#        'position': ['over', 'under']}}},
#     {'site_key': 'intertops',
#      'site_nice': 'Intertops',
#      'last_update': 1596907547,
#      'odds': {'totals': {'points': [234.0, 234.0],
#        'odds': [1.9091, 1.9091],
#        'position': ['over', 'under']}}},
#     {'site_key': 'bovada',
#      'site_nice': 'Bovada',
#      'last_update': 1596907531,
#      'odds': {'totals': {'points': [234.0, 234.0],
#        'odds': [1.909091, 1.909091],
#        'position': ['over', 'under']}}},
#     {'site_key': 'bookmaker',
#      'site_nice': 'Bookmaker',
#      'last_update': 1596907444,
#      'odds': {'totals': {'position': ['over', 'under'],
#        'odds': [1.909, 1.909],
#        'points': [234.0, 234.0]}}},
#     {'site_key': 'mybookieag',
#      'site_nice': 'MyBookie.ag',
#      'last_update': 1596907533,
#      'odds': {'totals': {'points': ['234.0', '234.0'],
#        'odds': [1.91, 1.91],
#        'position': ['over', 'under']}}},
#     {'site_key': 'williamhill_us',
#      'site_nice': 'William Hill (US)',
#      'last_update': 1596907551,
#      'odds': {'totals': {'points': [234.0, 234.0],
#        'odds': [1.91, 1.91],
#        'position': ['over', 'under']}}}],
#    'sites_count': 10},
#   {'sport_key': 'basketball_nba',
#    'sport_nice': 'NBA',
#    'teams': ['Denver Nuggets', 'Los Angeles Lakers'],
#    'commence_time': 1597108200,
#    'home_team': 'Los Angeles Lakers',
#    'sites': [],
#    'sites_count': 0}]}

# %%
def s_api(data):
    team = []
    home = []
    date = []
    home_odds = []
    away_odds = []
    odds = []
    
    for game in range(len(data['data'])):
        event = data['data'][game]
        team.append(event['teams'][0])
        team.append(event['teams'][1])
        home.append(1)
        home.append(0)
        time = dt.datetime.fromtimestamp(int(event['commence_time'])).strftime('%Y-%m-%d')
        date.append(time)
        date.append(time)
        home_odds = []
        away_odds = []
        for site in range(len(event['sites'])):
            h_odd = event['sites'][site]['odds']['spreads']['points'][0]
            a_odd = event['sites'][site]['odds']['spreads']['points'][1]    
            home_odds.append(float(h_odd))
            away_odds.append(float(a_odd))
        if event['sites_count'] == 0:
            odds.append('NaN')
            odds.append('NaN')
        else:
            h_odds = sum(home_odds)/len(home_odds)
            a_odds = sum(away_odds)/len(away_odds)
            odds.append(h_odds)
            odds.append(a_odds)
        
    game_dict = {
        "Team": team,
        "Date": date,
        "Home": home,
        "Spread": odds
    }
    df = pd.DataFrame(game_dict)
    df = df.round({'Spread':1})
    return df

def ml_api(data):
    team = []
    home = []
    date = []
    home_odds = []
    away_odds = []
    odds = []
    
    for game in range(len(data['data'])):
        event = data['data'][game]
        team.append(event['teams'][0])
        team.append(event['teams'][1])
        home.append(1)
        home.append(0)
        time = dt.datetime.fromtimestamp(int(event['commence_time'])).strftime('%Y-%m-%d')
        date.append(time)
        date.append(time)
        home_odds = []
        away_odds = []
        for site in range(len(event['sites'])):
            h_odd = event['sites'][site]['odds']['h2h'][0]
            a_odd = event['sites'][site]['odds']['h2h'][1]  
            home_odds.append(h_odd)
            away_odds.append(a_odd)
        if event['sites_count'] == 0:
            odds.append('NaN')
            odds.append('NaN')
        else:
            h_odds = sum(home_odds)/len(home_odds)
            a_odds = sum(away_odds)/len(away_odds)
            if h_odds > 2:
                h_odds = round((h_odds - 1) * 100)
            elif h_odds == 1:
                h_odds = 'NaN'
            elif h_odds < 2:
                h_odds = round(100 / (1 - h_odds))
            else:
                h_odds = 100
            if a_odds > 2:
                a_odds = round((a_odds - 1) * 100)
            elif a_odds == 1:
                a_odds = 'NaN'
            elif a_odds < 2:
                a_odds = round(100 / (1 - a_odds))
            else:
                a_odds = 100
            odds.append(h_odds)
            odds.append(a_odds)
        
    game_dict = {
        "Team": team,
        "Date": date,
        "Home": home,
        "ML": odds
    }
    df = pd.DataFrame(game_dict)
    df = df.round({'ML':0})
    return df

def t_api(data):
    team = []
    home = []
    date = []
    t = []
    home_odds = []
    away_odds = []
    odds = []
    
    for game in range(len(data['data'])):
        event = data['data'][game]
        team.append(event['teams'][0])
        team.append(event['teams'][1])
        home.append(1)
        home.append(0)
        time = dt.datetime.fromtimestamp(int(event['commence_time'])).strftime('%Y-%m-%d')
        date.append(time)
        date.append(time)
        home_odds = []
        away_odds = []
        for site in range(len(event['sites'])):
            h_odd = event['sites'][site]['odds']['totals']['points'][0]
            a_odd = event['sites'][site]['odds']['totals']['points'][1]    
            home_odds.append(float(h_odd))
            away_odds.append(float(a_odd))
        if event['sites_count'] == 0:
            odds.append('NaN')
            odds.append('NaN')
        else:
            h_odds = sum(home_odds)/len(home_odds)
            a_odds = sum(away_odds)/len(away_odds)
            odds.append(h_odds)
            odds.append(a_odds)
        
    game_dict = {
        "Team": team,
        "Date": date,
        "Home": home,
        "Over": odds
    }
    df = pd.DataFrame(game_dict)
    df = df.round({'Over':1})
    return df

# %%
ml_df = ml_api(ml_response)
ml_df.to_csv('ml_input.csv')
ml_df
# Out:
#                       Team        Date  Home   ML
# 0     Los Angeles Clippers  2020-08-08     1  165
# 1   Portland Trail Blazers  2020-08-08     0 -198
# 2           Denver Nuggets  2020-08-08     1 -123
# 3                Utah Jazz  2020-08-08     0  104
# 4           Indiana Pacers  2020-08-08     1  207
# 5       Los Angeles Lakers  2020-08-08     0 -248
# 6               Miami Heat  2020-08-08     1  113
# 7             Phoenix Suns  2020-08-08     0 -132
# 8         Dallas Mavericks  2020-08-08     1  186
# 9          Milwaukee Bucks  2020-08-08     0 -222
# 10          Denver Nuggets  2020-08-10     1  102
# 11      Los Angeles Lakers  2020-08-10     0 -120

# %%
s_df = s_api(s_response)
s_df.to_csv('s_input.csv')
#s_df

# %%
t_df = t_api(t_response)
t_df.to_csv('t_input.csv')
#t_df

# %%
odds_df = pd.merge(pd.merge(ml_df,s_df,on=['Team']),t_df,on=['Team'])
cols = [1,2,4,5]
odds_df.drop(odds_df.columns[cols],axis=1,inplace=True)
odds_df
# Out:
#                       Team   ML  Spread        Date  Home     Over
# 0     Los Angeles Clippers  165     4.7  2020-08-08     1  236.786
# 1   Portland Trail Blazers -198    -4.7  2020-08-08     0  236.786
# 2           Denver Nuggets -123    -1.5  2020-08-08     1  221.667
# 3           Denver Nuggets -123    -1.5  2020-08-10     1      NaN
# 4           Denver Nuggets -123     1.5  2020-08-08     1  221.667
# 5           Denver Nuggets -123     1.5  2020-08-10     1      NaN
# 6           Denver Nuggets  102    -1.5  2020-08-08     1  221.667
# 7           Denver Nuggets  102    -1.5  2020-08-10     1      NaN
# 8           Denver Nuggets  102     1.5  2020-08-08     1  221.667
# 9           Denver Nuggets  102     1.5  2020-08-10     1      NaN
# 10               Utah Jazz  104     1.5  2020-08-08     0  221.667
# 11          Indiana Pacers  207     6.0  2020-08-08     1  218.667
# 12      Los Angeles Lakers -248    -6.0  2020-08-08     0  218.667
# 13      Los Angeles Lakers -248    -6.0  2020-08-10     0      NaN
# 14      Los Angeles Lakers -248    -1.5  2020-08-08     0  218.667
# 15      Los Angeles Lakers -248    -1.5  2020-08-10     0      NaN
# 16      Los Angeles Lakers -120    -6.0  2020-08-08     0  218.667
# 17      Los Angeles Lakers -120    -6.0  2020-08-10     0      NaN
# 18      Los Angeles Lakers -120    -1.5  2020-08-08     0  218.667
# 19      Los Angeles Lakers -120    -1.5  2020-08-10     0      NaN
# 20              Miami Heat  113     2.0  2020-08-08     1  225.833
# 21            Phoenix Suns -132    -2.0  2020-08-08     0  225.833
# 22        Dallas Mavericks  186     5.5  2020-08-08     1   234.05
# 23         Milwaukee Bucks -222    -5.5  2020-08-08     0   234.05

# %%
odds_df = odds_df.replace({'Team': {'Atlanta Hawks':'ATL','Boston Celtics':'BOS','Brooklyn Nets':'BRK',
                          'Charlotte Hornets':'CHO','Chicago Bulls':'CHI','Cleveland Cavaliers':'CLE',
                          'Dallas Mavericks':'DAL','Denver Nuggets':'DEN','Detroit Pistons':'DET',
                          'Golden State Warriors':'GSW','Houston Rockets':'HOU','Indiana Pacers':'IND',
                          'Los Angeles Clippers':'LAC','Los Angeles Lakers':'LAL','Memphis Grizzlies':'MEM',
                          'Miami Heat':'MIA','Milwaukee Bucks':'MIL','Minnesota Timberwolves':'MIN',
                          'New Orleans Pelicans':'NOP','New York Knicks':'NYK','Oklahoma City Thunder':'OKC',
                          'Orlando Magic':'ORL','Philadelphia 76ers':'PHI','Phoenix Suns':'PHO',
                          'Portland Trail Blazers':'POR','Sacramento Kings':'SAC','San Antonio Spurs':'SAS',
                          'Toronto Raptors':'TOR','Utah Jazz':'UTA','Washington Wizards':'WAS'
                    }})
odds_df
# Out:
#    Team   ML  Spread        Date  Home     Over
# 0   LAC  165     4.7  2020-08-08     1  236.786
# 1   POR -198    -4.7  2020-08-08     0  236.786
# 2   DEN -123    -1.5  2020-08-08     1  221.667
# 3   DEN -123    -1.5  2020-08-10     1      NaN
# 4   DEN -123     1.5  2020-08-08     1  221.667
# 5   DEN -123     1.5  2020-08-10     1      NaN
# 6   DEN  102    -1.5  2020-08-08     1  221.667
# 7   DEN  102    -1.5  2020-08-10     1      NaN
# 8   DEN  102     1.5  2020-08-08     1  221.667
# 9   DEN  102     1.5  2020-08-10     1      NaN
# 10  UTA  104     1.5  2020-08-08     0  221.667
# 11  IND  207     6.0  2020-08-08     1  218.667
# 12  LAL -248    -6.0  2020-08-08     0  218.667
# 13  LAL -248    -6.0  2020-08-10     0      NaN
# 14  LAL -248    -1.5  2020-08-08     0  218.667
# 15  LAL -248    -1.5  2020-08-10     0      NaN
# 16  LAL -120    -6.0  2020-08-08     0  218.667
# 17  LAL -120    -6.0  2020-08-10     0      NaN
# 18  LAL -120    -1.5  2020-08-08     0  218.667
# 19  LAL -120    -1.5  2020-08-10     0      NaN
# 20  MIA  113     2.0  2020-08-08     1  225.833
# 21  PHO -132    -2.0  2020-08-08     0  225.833
# 22  DAL  186     5.5  2020-08-08     1   234.05
# 23  MIL -222    -5.5  2020-08-08     0   234.05

# %%
odds_df.to_csv('odds_input.csv')
