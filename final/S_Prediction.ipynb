# %%
import pandas as pd
from keras.models import Sequential, model_from_json
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("raw_input.csv")
cols = [0,1]
df2 = df.drop(df.columns[cols],axis=1)
df2 = df2.fillna(100)
df2
# Out:
#     Home   ML  Spread   Over  season_wins  net_points  avg_for_fg  \
# 0      1  245     6.1  231.8           34       -80.3        42.5
# 1      0 -295    -6.1  231.8           35       -81.4        42.2
# 2      1 -154    -3.2  218.7           46       153.3        42.0
# 3      0  134     3.2  218.7           44       180.0        40.1
# 4      1  369     9.6  223.7           35       -36.0        40.4
# 5      0 -469    -9.6  223.7           53       453.6        40.2
# 6      1 -217    -5.5  220.0           48       460.8        41.3
# 7      0  184     5.5  220.0           43       167.9        41.1
# 8      1  198     5.8  230.7           43       367.5        41.7
# 9      0 -238    -5.8  230.7           49       460.8        41.6
# 10     1 -748   -11.2  224.5           56       737.3        43.3
# 11     0  544    11.2  224.5           33       -73.0        39.3
# 12     1  156     3.8  217.2           45       138.7        42.1
# ...

# %%
# def load_model():
#     # loading model
#     model = model_from_json(open('ML_model_architecture.json').read())
#     model.load_weights('ML_model_weights.h5')
#     model.compile(loss='categorical_crossentropy', optimizer='adam')
#     return model

# %%
from joblib import dump, load
rf = load('spread_model.joblib')
clf = load('s_payout_model.joblib')

# %%
predictions_s = rf.predict(df2).tolist()
predictions_po = clf.predict(df2).tolist()
df.drop(df.columns[5:],axis=1,inplace=True)
df['s_outcome'] = predictions_s
df['exp_payout'] = predictions_po
cols = [0,3]
df.drop(df.columns[cols],axis=1,inplace=True)
df
# Out:
#    Team  Home  Spread  s_outcome  exp_payout
# 0   MEM     1     6.1          1   16.062392
# 1   POR     0    -6.1          0   -6.030412
# 2   DEN     1    -3.2          1   -2.107458
# 3   UTA     0     3.2          1    8.977892
# 4   BRK     1     9.6          1   15.382925
# 5   TOR     0    -9.6          1    5.850517
# 6   BOS     1    -5.5          1    2.728047
# 7   PHI     0     5.5          1   13.235193
# 8   DAL     1     5.8          1    8.599649
# 9   LAC     0    -5.8          0   -0.056510
# 10  MIL     1   -11.2          1   -5.153761
# 11  ORL     0    11.2          1   19.899068
# 12  IND     1     3.8          1   14.095113
# 13  MIA     0    -3.8          1   12.471413
# 14  HOU     1     1.5          1    0.431987
# 15  OKC     0    -1.5          1    2.225119

# %%
# load
# model = load_model()

# # predictions
# predictions = model.predict_classes(df2, verbose=2)
# print(predictions)

# %%
# p = predictions.tolist()
# df['ml_outcome'] = p
# cols = [0,2,5,6,7,8]
# df.drop(df.columns[cols],axis=1,inplace=True)
# df

# %%
df.to_csv('s_predictions.csv')
